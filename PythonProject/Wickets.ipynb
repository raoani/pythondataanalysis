# %%
import glob
import pandas as pd
import numpy as np
from datetime import datetime
import os
import sys
dict_1 = {}
dict_2 = {}
g = (glob.glob(r'C:\Users\aniru\Desktop\Season\*.csv'))
s_8 = pd.read_csv(g[8])
s_8 = s_8.set_index(['batting_team'] ,drop = False )
s_8 = s_8[s_8['batting_team'] == 'Sunrisers Hyderabad' ]
a = s_8.match_id.unique().tolist()

# %%
for i in a :
    s_9 = s_8[s_8['match_id'] == i]
    list_3 = s_9.batting_team.unique().tolist()
    z = s_9.over.unique().tolist()
    l = []
    for k in z :
        l.append(len((s_9[s_9['over']==k]['player_dismissed']).unique()))
        x = [v - 1 for v in l]
        dict_2[i] = [sum(x[:5]) , sum(x[5:10]), sum(x[10:15]), sum(x[15:])]
    list_3 = []
    dict_1['Sunrisers Hyderabad'] = dict_2
dict_1
# Out:
# {'Sunrisers Hyderabad': {521: [1, 2, 2, 1],
#   525: [2, 2, 0, 3],
#   529: [1, 0, 2, 0],
#   532: [0, 0, 0, 0],
#   535: [0, 2, 1, 2],
#   539: [2, 3, 0, 3],
#   544: [1, 0, 0, 4],
#   551: [2, 1, 1, 1],
#   554: [0, 1, 1, 1],
#   557: [1, 0, 1, 6],
#   559: [0, 1, 2, 5],
#   563: [0, 1, 1, 1],
#   569: [0, 3, 1, 3],
#   572: [1, 0, 3, 4],
#   575: [1, 2, 0, 5],
#   576: [2, 1, 2, 1],
#   577: [0, 2, 1, 4]}}

# %%
import numpy as np
from datetime import datetime
import os
import sys
dict_1 = {}
dict_2 = {}
g = (glob.glob(r'C:\Users\aniru\Desktop\Season\*.csv'))
s_8 = pd.read_csv(g[7])
s_8 = s_8[s_8['dl_applied']==0]
list_1 = s_8.match_id.unique().tolist()
list_2 = s_8.team1.unique().tolist()
list_2
s_8 = s_8.set_index(['batting_team'] , drop = False)

# %%
dict_3 = {}
print(list_2)
for j in list_2 :
    s_9 = s_8[s_8['batting_team'] == j]
    s_9 = s_9.set_index(['batting_team'] , drop = False)
    x = len(s_9.match_id.unique())
    a = s_9.over.unique().tolist()
    for k in a :
        l.append(len((s_9[s_9['over']==k]['player_dismissed']).unique()))
        x = [v - 1 for v in l]
        #dict_3[j] = [sum(x[:5]) , sum(x[5:10]), sum(x[10:15]), sum(x[15:])]
        dict_3[j] = x
    l = []
    print(j)
print(x)
# Out:
# ['Mumbai Indians', 'Chennai Super Kings', 'Rajasthan Royals', 'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab', 'Royal Challengers Bangalore', 'Sunrisers Hyderabad']
# Mumbai Indians
# Chennai Super Kings
# Rajasthan Royals
# Kolkata Knight Riders
# Delhi Daredevils
# Kings XI Punjab
# Royal Challengers Bangalore
# Sunrisers Hyderabad
# [3, 2, 0, 1, 2, 4, 2, 1, 3, 4, 2, 3, 2, 1, 6, 3, 4, 6, 4, 5]

# %%
dict_3
# Out:
# {'Chennai Super Kings': [2,
#   1,
#   2,
#   2,
#   3,
#   5,
#   2,
#   3,
#   2,
#   3,
#   2,
#   2,
#   5,
#   2,
#   4,
#   5,
#   4,
#   4,
#   6,
#   5],
#  'Delhi Daredevils': [2,
#   1,
#   4,
#   0,
#   3,
#   2,
#   4,
#   1,
#   3,
#   2,
#   2,
#   3,
#   2,
#   5,
#   3,
#   4,
#   3,
#   4,
#   6,
#   5],
#  'Kings XI Punjab': [5,
#   2,
#   3,
#   3,
#   5,
#   5,
#   4,
#   2,
#   8,
#   4,
#   3,
#   3,
#   3,
#   4,
#   3,
#   2,
#   3,
#   5,
#   5,
#   6],
#  'Kolkata Knight Riders': [1,
#   0,
#   1,
#   2,
#   3,
#   2,
#   3,
#   3,
#   4,
#   2,
#   3,
#   2,
#   1,
#   4,
#   5,
#   2,
#   4,
#   6,
#   2,
#   5],
#  'Mumbai Indians': [3,
#   2,
#   1,
#   4,
#   3,
#   5,
#   3,
#   1,
#   2,
#   3,
#   4,
#   3,
#   2,
#   3,
#   2,
#   2,
#   3,
#   4,
#   4,
#   8],
#  'Rajasthan Royals': [3,
#   2,
#   1,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   2,
#   4,
#   3,
#   2,
#   2,
#   5,
#   3,
#   2,
#   6,
#   7,
#   6],
# ...
