# %%
import glob
import pandas as pd
import numpy as np
from datetime import datetime
import os
import sys
dict_1 = {}
dict_2 = {}
g = (glob.glob(r'C:\Users\aniru\Desktop\Season\*.csv'))
s_8 = pd.read_csv(g[8])
s_8 = s_8.set_index(['match_id'] ,drop = False )
s_8 = s_8[s_8['match_id']==539]
s_8 = s_8[s_8['batting_team'] == 'Sunrisers Hyderabad' ]
# dont run

# %%
s_8 = s_8[s_8['batting_team']=='Kolkata Knight Riders']
a = s_8.over.unique().tolist()
# dont run

# %%
z = []
for i in a :
    z.append(sum(s_8[s_8['over']==i]['batsman_runs']))
# Out:
# [0, 4, 5, 10, 6]

# %%
import numpy as np
from datetime import datetime
import os
import sys
dict_1 = {}
dict_2 = {}
g = (glob.glob(r'C:\Users\aniru\Desktop\Season\*.csv'))
s_8 = pd.read_csv(g[8])
s_8 = s_8[s_8['dl_applied']==0]
list_1 = s_8.match_id.unique().tolist()
list_2 = s_8.team1.unique().tolist()
a = []
#dont run

# %%
for i in list_1 :
    s_9 = s_8[s_8['match_id']==i]
    list_3 = s_9.batting_team.unique().tolist()
    #print(list_3)
    for j in list_3 :
        a = []
        s_10 = s_9[s_9['batting_team'] == j]
        a = s_10.over.unique().tolist()
        z = []
        for k in a :
            z.append(sum(s_10[s_10['over']==k]['batsman_runs']))
            dict_2[j] = [np.average(z[:5]) , np.average(z[5:10]) , np.average(z[10:15]) , np.average(z[15:20])]
    list_3 = []
    dict_1[i] = dict_2
    dict_2 = {}
# dont run
# Out:
# C:\Users\aniru\Anaconda3\lib\site-packages\numpy\core\_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# C:\Users\aniru\Anaconda3\lib\site-packages\numpy\core\_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
dict_1
# dont run
# Out:
# {518: {'Mumbai Indians': [5.0, 2.2000000000000002, 4.0, 10.4],
#   'Rising Pune Supergiants': [7.4000000000000004,
#    7.5999999999999996,
#    9.1999999999999993,
#    nan]},
#  519: {'Delhi Daredevils': [6.5999999999999996, 4.0, 5.4000000000000004, 2.0],
#   'Kolkata Knight Riders': [8.0, 3.7999999999999998, 5.7999999999999998, nan]},
#  520: {'Gujarat Lions': [8.5999999999999996, 10.4, 6.7999999999999998, 9.0],
#   'Kings XI Punjab': [9.0, 7.7999999999999998, 7.0, 7.0]},
#  521: {'Royal Challengers Bangalore': [8.1999999999999993,
#    9.0,
#    13.199999999999999,
#    13.6],
#   'Sunrisers Hyderabad': [8.8000000000000007,
#    8.1999999999999993,
#    9.0,
#    8.1999999999999993]},
#  522: {'Kolkata Knight Riders': [6.2000000000000002,
#    8.8000000000000007,
#    11.0,
#    9.4000000000000004],
#   'Mumbai Indians': [9.1999999999999993,
#    6.2000000000000002,
#    10.4,
#    9.8000000000000007]},
#  523: {'Gujarat Lions': [8.0, 9.0, 7.2000000000000002, 7.0],
# ...

# %%
list_4 = s_8.batting_team.unique().tolist()
list_4
d = []
#dont run

# %%
for keys, values in dict_1.items() :
    d = values.values()
d
# dont run
# Out:
# dict_values([[8.8000000000000007, 9.8000000000000007, 8.4000000000000004, 11.800000000000001], [10.0, 11.199999999999999, 9.1999999999999993, 7.7999999999999998]])

# %%
import numpy as np
from datetime import datetime
import os
import sys
dict_1 = {}
dict_2 = {}
g = (glob.glob(r'C:\Users\aniru\Desktop\Season\*.csv'))
s_8 = pd.read_csv(g[7])
s_8 = s_8[s_8['dl_applied']==0]
list_1 = s_8.match_id.unique().tolist()
list_2 = s_8.team1.unique().tolist()
list_2
s_8 = s_8.set_index(['batting_team'] , drop = False)

# %%
#print(list_3) #Do not Run
for j in list_2 :
    a = []
    s_10 = s_9[s_9['batting_team'] == j]
    a = s_10.over.unique().tolist()
    z = []
    for k in a :
        z.append(sum(s_10[s_10['over']==k]['batsman_runs']))
        dict_2[j] = [sum(z[:5]) , sum(z[5:10]) , sum(z[10:15]) , sum(z[15:20])]
list_3 = []
dict_1[i] = dict_2
dict_2 = {}
# dont not run

# %%
dict_3 = {}
print(list_2)
for j in list_2 :
    s_9 = s_8[s_8['batting_team'] == j]
    s_9 = s_9.set_index(['batting_team'] , drop = False)
    x = len(s_9.match_id.unique())
    a = s_9.over.unique().tolist()
    for k in a :
        z.append(round(sum(s_9[s_9['over']==k]['batsman_runs'])/x))
        dict_3[j] = [sum(z[:5]) , sum(z[5:10]) , sum(z[10:15]) , sum(z[15:20])]
    z = []
    print(j)
print(x)
# Out:
# ['Mumbai Indians', 'Chennai Super Kings', 'Rajasthan Royals', 'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab', 'Royal Challengers Bangalore', 'Sunrisers Hyderabad']
# Mumbai Indians
# Chennai Super Kings
# Rajasthan Royals
# Kolkata Knight Riders
# Delhi Daredevils
# Kings XI Punjab
# Royal Challengers Bangalore
# Sunrisers Hyderabad
# 12

# %%
s_8 = s_8[s_8['batting_team'] == 'Royal Challengers Bangalore']
s_8
#dont run
# Out:
#                              season  match_id  season.1       city  \
# batting_team
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# Royal Challengers Bangalore    2016       521      2016  Bangalore
# ...

# %%
dict_3
# Out:
# {'Chennai Super Kings': [38.0, 34.0, 36.0, 42.0],
#  'Delhi Daredevils': [34.0, 34.0, 40.0, 40.0],
#  'Kings XI Punjab': [36.0, 31.0, 33.0, 37.0],
#  'Kolkata Knight Riders': [39.0, 35.0, 40.0, 40.0],
#  'Mumbai Indians': [35.0, 34.0, 40.0, 55.0],
#  'Rajasthan Royals': [34.0, 39.0, 39.0, 45.0],
#  'Royal Challengers Bangalore': [34.0, 36.0, 35.0, 38.0],
#  'Sunrisers Hyderabad': [39.0, 33.0, 36.0, 45.0]}
