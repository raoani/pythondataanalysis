# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
import sys
dict_1 = {}
dict_2 = {}
s_9 = pd.read_csv(r'C:\Users\aniru\Desktop\PythonProject\matches.csv')
s_9 = s_9.set_index(keys=['result'], drop = False)
s_9 = s_9[s_9['result']=='normal']
s_9
# Out:
#          id  season           city        date                        team1  \
# result
# normal    1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# normal    2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# normal    3    2008          Delhi  2008-04-19             Rajasthan Royals
# normal    4    2008         Mumbai  2008-04-20               Mumbai Indians
# normal    5    2008        Kolkata  2008-04-20              Deccan Chargers
# normal    6    2008         Jaipur  2008-04-21              Kings XI Punjab
# normal    7    2008      Hyderabad  2008-04-22              Deccan Chargers
# normal    8    2008        Chennai  2008-04-23          Chennai Super Kings
# normal    9    2008      Hyderabad  2008-04-24              Deccan Chargers
# normal   10    2008     Chandigarh  2008-04-25              Kings XI Punjab
# normal   11    2008      Bangalore  2008-04-26  Royal Challengers Bangalore
# ...

# %%
s_9 = s_9.set_index(keys=['toss_winner'], drop = False)
s_9 = s_9[s_9['season']==2008]
s_9
# Out:
#                              id  season        city        date  \
# toss_winner
# Royal Challengers Bangalore   1    2008   Bangalore  2008-04-18
# Chennai Super Kings           2    2008  Chandigarh  2008-04-19
# Rajasthan Royals              3    2008       Delhi  2008-04-19
# Mumbai Indians                4    2008      Mumbai  2008-04-20
# Deccan Chargers               5    2008     Kolkata  2008-04-20
# Kings XI Punjab               6    2008      Jaipur  2008-04-21
# Deccan Chargers               7    2008   Hyderabad  2008-04-22
# Mumbai Indians                8    2008     Chennai  2008-04-23
# Rajasthan Royals              9    2008   Hyderabad  2008-04-24
# Mumbai Indians               10    2008  Chandigarh  2008-04-25
# Rajasthan Royals             11    2008   Bangalore  2008-04-26
# Kolkata Knight Riders        12    2008     Chennai  2008-04-26
# Deccan Chargers              13    2008      Mumbai  2008-04-27
# ...

# %%
s_9[s_9['toss_decision']=='bat']['winner'].value_counts()
# Out:
# Chennai Super Kings            6
# Kolkata Knight Riders          5
# Rajasthan Royals               4
# Kings XI Punjab                4
# Royal Challengers Bangalore    3
# Delhi Daredevils               3
# Mumbai Indians                 1
# Name: winner, dtype: int64

# %%
s_9[s_9['toss_winner']=='Deccan Chargers']['winner'].value_counts()
# Out:
# Deccan Chargers                2
# Delhi Daredevils               2
# Royal Challengers Bangalore    2
# Mumbai Indians                 1
# Kolkata Knight Riders          1
# Chennai Super Kings            1
# Name: winner, dtype: int64

# %%
s_9 = s_9.set_index(keys=['toss_decision'], drop = False)
s_9
# Out:
#                id  season        city        date  \
# toss_decision
# field           1    2008   Bangalore  2008-04-18
# bat             2    2008  Chandigarh  2008-04-19
# bat             3    2008       Delhi  2008-04-19
# bat             4    2008      Mumbai  2008-04-20
# bat             5    2008     Kolkata  2008-04-20
# bat             6    2008      Jaipur  2008-04-21
# bat             7    2008   Hyderabad  2008-04-22
# field           8    2008     Chennai  2008-04-23
# field           9    2008   Hyderabad  2008-04-24
# field          10    2008  Chandigarh  2008-04-25
# field          11    2008   Bangalore  2008-04-26
# bat            12    2008     Chennai  2008-04-26
# field          13    2008      Mumbai  2008-04-27
# bat            14    2008  Chandigarh  2008-04-27
# bat            15    2008   Bangalore  2008-04-28
# bat            16    2008     Kolkata  2008-04-29
# field          17    2008       Delhi  2008-04-30
# ...

# %%
s_9[s_9['toss_decision']=='bat']
# Out:
#                              id  season        city        date  \
# toss_winner
# Chennai Super Kings           2    2008  Chandigarh  2008-04-19
# Rajasthan Royals              3    2008       Delhi  2008-04-19
# Mumbai Indians                4    2008      Mumbai  2008-04-20
# Deccan Chargers               5    2008     Kolkata  2008-04-20
# Kings XI Punjab               6    2008      Jaipur  2008-04-21
# Deccan Chargers               7    2008   Hyderabad  2008-04-22
# Kolkata Knight Riders        12    2008     Chennai  2008-04-26
# Delhi Daredevils             14    2008  Chandigarh  2008-04-27
# Chennai Super Kings          15    2008   Bangalore  2008-04-28
# Kolkata Knight Riders        16    2008     Kolkata  2008-04-29
# Rajasthan Royals             19    2008      Jaipur  2008-05-01
# Chennai Super Kings          20    2008     Chennai  2008-05-02
# Deccan Chargers              21    2008   Hyderabad  2008-05-25
# ...

# %%
s_9[s_9["toss_winner"]==s_9['winner']]['winner'].value_counts()
# Out:
# Rajasthan Royals               9
# Mumbai Indians                 4
# Kings XI Punjab                4
# Chennai Super Kings            3
# Kolkata Knight Riders          3
# Delhi Daredevils               2
# Deccan Chargers                2
# Royal Challengers Bangalore    1
# Name: winner, dtype: int64
